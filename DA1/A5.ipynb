# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random as rd
import sys
import seaborn as sns
import squarify as sq
import unicodedata

# %%
data=pd.read_csv(r"C:\Users\sujit\Downloads\newautos.csv", encoding_errors= 'replace')

# %%
datac=data.copy()

# %%
# 5) Is there any relationship between dollar_price and kilometer? (Explain with appropriate analysis)

# %%
sns.scatterplot(x='kilometer', y='price', data=datac)
plt.xlabel('Kilometer')
plt.ylabel('Dollar Price')
plt.title('Scatter Plot of Dollar Price vs. Kilometer')
plt.show()
# Out:
# C:\Users\sujit\Desktop\da\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\sujit\Desktop\da\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
datac
# Out:
#         Unnamed: 0          dateCrawled  \
# 0                0  2016-03-24 11:52:17
# 1                1  2016-03-24 10:58:45
# 2                2  2016-03-14 12:52:21
# 3                3  2016-03-17 16:54:04
# 4                4  2016-03-31 17:25:20
# ...            ...                  ...
# 371523      371523  2016-03-14 17:48:27
# 371524      371524  2016-03-05 19:56:21
# 371525      371525  2016-03-19 18:57:12
# 371526      371526  2016-03-20 19:41:08
# 371527      371527  2016-03-07 19:39:19
#
#                                                 name  seller offerType  price  \
# 0                                         Golf_3_1.6  privat   Angebot    480
# 1                               A5_Sportback_2.7_Tdi  privat   Angebot  18300
# 2                     Jeep_Grand_Cherokee_"Overland"  privat   Angebot   9800
# 3                                 GOLF_4_1_4__3T�RER  privat   Angebot   1500
# 4                     Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot   3600
# ...

# %%
from scipy.stats import pearsonr

corr, p_value = pearsonr(datac['price'], datac['kilometer'])
print("Pearson correlation coefficient:{}".format(corr))
print('p-value:{}'.format(p_value))
# Out:
# Pearson correlation coefficient:-0.0006353837845731562
# p-value:0.6985453557471916
