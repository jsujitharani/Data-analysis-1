# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random as rd
import sys
import seaborn as sns
import squarify as sq
import unicodedata

# %%
#1) Perform general Data analysis

# %%
data=pd.read_csv(r"C:\Users\sujit\Downloads\autos.csv", encoding_errors= 'replace')

# %%
datac=data.copy()

# %%
datac.shape
# Out:
# (371528, 20)

# %%
datac
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3T�RER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
datac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
# ...

# %%
datac.fillna({"vehicleType":"no type","gearbox":"not defined","model":"no model","fuelType":"no type","nrOfPictures":0,
              "notRepairedDamage":"not defined"},inplace=True)

# %%
datac["dateCrawled"]=pd.to_datetime(datac["dateCrawled"])
datac["dateCreated"]=pd.to_datetime(datac["dateCreated"])
datac["lastSeen"]=pd.to_datetime(datac["lastSeen"])

# %%
datac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  datetime64[ns]
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          371528 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              371528 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                371528 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             371528 non-null  object
# ...

# %%
datac.describe()
# Out:
#                          dateCrawled         price  yearOfRegistration  \
# count                         371528  3.715280e+05       371528.000000
# mean   2016-03-21 13:30:31.202717184  1.729514e+04         2004.577997
# min              2016-03-05 14:06:22  0.000000e+00         1000.000000
# 25%       2016-03-13 12:51:46.500000  1.150000e+03         1999.000000
# 50%              2016-03-21 18:36:22  2.950000e+03         2003.000000
# 75%    2016-03-29 14:49:31.249999872  7.200000e+03         2008.000000
# max              2016-04-07 14:36:58  2.147484e+09         9999.000000
# std                              NaN  3.587954e+06           92.866598
#
#              powerPS      kilometer  monthOfRegistration  \
# count  371528.000000  371528.000000        371528.000000
# mean      115.549477  125618.688228             5.734445
# min         0.000000    5000.000000             0.000000
# 25%        70.000000  125000.000000             3.000000
# ...

# %%
datac.describe(include="all")
# Out:
#                           dateCrawled         name  seller offerType  \
# count                          371528       371528  371528    371528
# unique                            NaN       233528       2         2
# top                               NaN  Ford_Fiesta  privat   Angebot
# freq                              NaN          657  371525    371516
# mean    2016-03-21 13:30:31.202717184          NaN     NaN       NaN
# min               2016-03-05 14:06:22          NaN     NaN       NaN
# 25%        2016-03-13 12:51:46.500000          NaN     NaN       NaN
# 50%               2016-03-21 18:36:22          NaN     NaN       NaN
# 75%     2016-03-29 14:49:31.249999872          NaN     NaN       NaN
# max               2016-04-07 14:36:58          NaN     NaN       NaN
# std                               NaN          NaN     NaN       NaN
#
#                price  abtest vehicleType  yearOfRegistration  gearbox  \
# ...

# %%
#datac.to_csv(r"C:\Users\sujit\Downloads\newautos.csv")
